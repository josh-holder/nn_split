# %%
time_data_path = 'test2/trainiter1_core1_timedata_df.pkl'

# %%
import pickle
with open(time_data_path,'rb') as f:
    data = pickle.load(f)
data
# Out:
#              0                               1                       \
#        nn_time splt_time total_time    nn_time splt_time total_time
# 0    15.703650  1.951955  17.795249  22.216504  1.145983  23.501523
# 1    13.963973  1.272875  15.530435  22.320387  2.455931  25.005371
# 2    14.409981  1.235345  15.792369  22.155019  1.686005  23.977955
# 3    14.184350  1.571288  15.875023  22.201773  1.494207  23.917001
# 4    17.451194  2.041825  19.631322  24.421166  1.348690  25.933236
# ..         ...       ...        ...        ...       ...        ...
# 135        NaN       NaN        NaN        NaN       NaN        NaN
# 136        NaN       NaN        NaN        NaN       NaN        NaN
# 137        NaN       NaN        NaN        NaN       NaN        NaN
# 138        NaN       NaN        NaN        NaN       NaN        NaN
# 139        NaN       NaN        NaN        NaN       NaN        NaN
#
#              2                               3                       \
# ...

# %%
for time in data.loc[:,(2,'nn_time')]:
    print(time)
# Out:
# 26.449950456619263
# 23.26859188079834
# 25.2926344871521
# 26.728777408599854
# 27.11658763885498
# 27.627262592315674
# 24.037970066070557
# 27.08260726928711
# 27.93965244293213
# 25.52139139175415
# 22.591294288635254
# 27.205326795578003
# 28.302637815475464
# 25.701781272888184
# 27.83588457107544
# 24.29781699180603
# 23.299476861953735
# 26.211263179779053
# 26.67829966545105
# 28.493574380874634
# 25.498169422149658
# 27.089934825897217
# 24.4141948223114
# 31.5201632976532
# 1827.7379212379456
# 29.64519739151001
# 4276.994772434235
# 7223.189567565918
# 33.15148615837097
# 27.14334535598755
# 24.091932773590088
# 4054.7097265720367
# 26.654274463653564
# 23.590553283691406
# 23.703826427459717
# 25.245875120162964
# 23.899828910827637
# 23.96024227142334
# 26.923136949539185
# 27.092569589614868
# 31.758490324020386
# 25.22814679145813
# 23.81332278251648
# 22.38403296470642
# 25.041165828704834
# 22.569066762924194
# 24.673216819763184
# 22.72298240661621
# ...

# %%
# Out:
#           0                              1
#     nn_time splt_time total_time   nn_time splt_time total_time
# 0  2.661600  0.925228   3.654996  2.343057  0.911836   3.323704
# 1  2.489342  1.123107   3.686990  2.437459  1.012414   3.522388
# 2  2.386707  1.553742   4.041396  2.406495  1.204895   3.691343
# 3  2.384886  1.412310   3.885861  2.480726  1.466453   4.071134
# 4  2.337364  1.172328   3.586086  2.355371  1.084248   3.513781
# 5  2.555046  1.322664   3.957729  2.469864  1.390916   3.943061
