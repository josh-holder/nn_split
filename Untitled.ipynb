# %%
time_data_path = 'time_test/trainiter1_core1_timedata_df.pkl'

# %%
import pickle
with open(time_data_path,'rb') as f:
    data = pickle.load(f)
data
# Out:
#              0                                 1                         \
#        nn_time splt_time total_time      nn_time splt_time   total_time
# 0    12.127156  1.078728  13.291429  1972.267905  2.285392  1974.685989
# 1    12.441558  1.871890  14.416787    19.632467  1.529397    21.333126
# 2    12.833692  1.434658  14.374533   905.169211  3.860753   909.308668
# 3    13.311479  2.197716  15.665942    19.740132  1.612974    21.449547
# 4    15.890917  2.228985  18.234916  7224.825908  4.659898  7229.728898
# ..         ...       ...        ...          ...       ...          ...
# 105        NaN       NaN        NaN          NaN       NaN          NaN
# 106        NaN       NaN        NaN          NaN       NaN          NaN
# 107        NaN       NaN        NaN          NaN       NaN          NaN
# 108        NaN       NaN        NaN          NaN       NaN          NaN
# 109        NaN       NaN        NaN          NaN       NaN          NaN
#
# ...

# %%
# Out:
#           0                              1
#     nn_time splt_time total_time   nn_time splt_time total_time
# 0  2.661600  0.925228   3.654996  2.343057  0.911836   3.323704
# 1  2.489342  1.123107   3.686990  2.437459  1.012414   3.522388
# 2  2.386707  1.553742   4.041396  2.406495  1.204895   3.691343
# 3  2.384886  1.412310   3.885861  2.480726  1.466453   4.071134
# 4  2.337364  1.172328   3.586086  2.355371  1.084248   3.513781
# 5  2.555046  1.322664   3.957729  2.469864  1.390916   3.943061
